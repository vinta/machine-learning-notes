# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# %%
# %%capture
# %run _prepare_data.ipynb

# %%
titanic = train
titanic_test = test

predictors = ["Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "Embarked"]

logistic = LogisticRegression(random_state=1)

# Compute the accuracy score for all the cross validation folds.  (much simpler than what we did before!)
scores = cross_val_score(logistic, titanic[predictors], titanic["Survived"], cv=3)

# Take the mean of the scores (because we have one for each fold)
print(scores.mean())
# Out:
# 0.787878787879

# %%
# Train the algorithm using all the training data
logistic.fit(titanic[predictors], titanic["Survived"])

# Make predictions using the test set.
prediction = logistic.predict(titanic_test[predictors])

# Create a new dataframe with only the columns Kaggle wants from the dataset.
solution = pd.DataFrame({
    "PassengerId": titanic_test["PassengerId"],
    "Survived": prediction
})

# %%
solution
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         1
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         1
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# ...

# %%
solution.to_csv('logistic_regression.csv', index=False)
